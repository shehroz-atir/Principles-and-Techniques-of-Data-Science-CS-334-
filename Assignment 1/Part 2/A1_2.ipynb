# %% [markdown]
# # **Assignment 1-Part 2**

# %% [markdown]
# Note: It should take you an estimated time of 2 hours to complete this part.
#
#
#
# # **Context about dataset**
#
# The titanic dataset is a record of passengers aboard the Titanic and their fates (whether or not they survived the incident). This includes socio-economic class divide between passengers, their ages, names, fares and even their passenger IDs. The principal source for data about Titanic passengers is the Encyclopedia Titanica. The datasets used here were begun by a variety of researchers. One of the original sources is Eaton & Haas (1994) Titanic: Triumph and Tragedy, Patrick Stephens Ltd, which includes a passenger list created by many researchers and edited by Michael A. Findlay.
#
# As we explore this data from titanic, it is your job to answer some pressing questions regarding the various age groups aboard, their economic statuses and survival rates in each gender. Following are some details about the variable to help you understand the data better. <br>

# %% [markdown]
# ## **VARIABLE DESCRIPTIONS** <br>
# Pclass ->   Passenger Class  (1 = 1st; 2 = 2nd; 3 = 3rd) <br>
# Survived ->  Did the passenger survive? (0 = No; 1 = Yes) <br>
# Name ->  name <br>
# Sex ->  sex
# Age ->  age  <br>
# SibSp ->  Number of Siblings/Spouses Aboard <br>
# Parch ->  Number of Parents/Children Aboard <br>
# Ticket ->   Ticket Number <br>
# Fare ->   Passenger Fare (British pound) <br>
# Cabin ->   Cabin <br>
# Embarked ->   Port of Embarkation (C = Cherbourg; Q = Queenstown; S = Southampton) <br>

# %% [markdown]
# # **Instructions**

# %% [markdown]
# How to run this on Google Colab: Uncomment the code cells below and place your csv files on Drive to run this assignment on Google Colab (only if you want to - jupyter notebooks work just fine)

# %%
'''
Linking google colab to your drive folder
'''
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)

# %%
'''
Place the csv files inside your drive and then run this cell
'''
# %cd /content/gdrive/My\ Drive/

# %% [markdown]
# #**Importing relevant libraries and reading data**

# %%
import pandas as pd
import numpy as np
import matplotlib

df_main = pd.read_csv('titanic.csv')

# %% [markdown]
# **Question 1:** Drop the `Cabin` column and save this new dataframe in a variable. Use this dataframe for all other questions.

# %%
import pandas as pd
import numpy as np
import matplotlib

df_main = pd.read_csv('titanic.csv')
df=df_main.drop("Cabin",axis=1)
df.head()
# Out:
#     Age Embarked     Fare                                               Name  \
# 0  22.0        S   7.2500                            Braund, Mr. Owen Harris
# 1  38.0        C  71.2833  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2  26.0        S   7.9250                             Heikkinen, Miss. Laina
# 3  35.0        S  53.1000       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4  35.0        S   8.0500                           Allen, Mr. William Henry
#
#    Parch  PassengerId  Pclass     Sex  SibSp  Survived            Ticket  \
# 0      0            1       3    male      1         0         A/5 21171
# 1      0            2       1  female      1         1          PC 17599
# 2      0            3       3  female      0         1  STON/O2. 3101282
# 3      0            4       1  female      1         1            113803
# 4      0            5       3    male      0         0            373450
#
#   Title  Family_Size
# 0    Mr            1
# 1   Mrs            1
# 2  Miss            0
# 3   Mrs            1
# 4    Mr            0

# %% [markdown]
# **Question 2:** Using the describe function, print the mean family size for this dataset.

# %%
fam_mean=df["Family_Size"].mean()
print(fam_mean)
# Out:
# 0.9046015712682379

# %% [markdown]
# **Question 3:** What percentage of people aboard the ship were females?

# %%
femalep=df[df["Sex"].isin(["female"])]
(femalep["Sex"].count()/df['Sex'].count())*100
# Out:
# 35.24130190796858

# %% [markdown]
# **Question 4:** Set the `PassengerID` of passengers as the index for this dataset.

# %%
df=df.sort_values("PassengerId", ascending = True)

# %% [markdown]
# **Question 5:** Convert all column names to lowercase and print the head of the dataframe. Also, remove spaces within column names (if any)

# %%
df.columns = df.columns.str.replace(' ', '') 
df.columns = map(str.lower, df.columns)
df.head()
# Out:
#     age embarked     fare                                               name  \
# 0  22.0        S   7.2500                            Braund, Mr. Owen Harris
# 1  38.0        C  71.2833  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2  26.0        S   7.9250                             Heikkinen, Miss. Laina
# 3  35.0        S  53.1000       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4  35.0        S   8.0500                           Allen, Mr. William Henry
#
#    parch  passengerid  pclass     sex  sibsp  survived            ticket  \
# 0      0            1       3    male      1         0         A/5 21171
# 1      0            2       1  female      1         1          PC 17599
# 2      0            3       3  female      0         1  STON/O2. 3101282
# 3      0            4       1  female      1         1            113803
# 4      0            5       3    male      0         0            373450
#
#   title  family_size
# 0    Mr            1
# 1   Mrs            1
# 2  Miss            0
# 3   Mrs            1
# 4    Mr            0

# %% [markdown]
# **Question 6:** Using a bar chart, visualize the count of passengers by gender who survived. Label the graph properly (title and axis names) Hint: You can use .plot.bar() function to solve this part.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.barplot(x = "sex", y = "survived", data = df)
plt.show()

# %% [markdown]
# **Question 7 Part A:** Were those who had siblings and spouses on board more likely to survive than those who did not. Demonstrate the reasoning behind your answer through code.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.barplot(x = "sibsp", y = "survived", data = df)
plt.show()

# %% [markdown]
# **Question 7 Part B:** Answer as 'Yes' or 'No' based on your code above.

# %%
Yes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-115-2ad6485b65ee> in <module>
# ----> 1 Yes
#
# NameError: name 'Yes' is not defined

# %% [markdown]
# **Question 8:** Were males more likely than females to survive?

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.barplot(x = "sex", y = "survived", data = df)
plt.show()

# %% [markdown]
# **Question 9:** Using the pandas iloc function, print the dataframe for ages between 5 to 20 and fare above 20.

# %%
#df.loc[(df["fare"]>20)& ((df["age"]>=5) &(df["age"]<=20))]
df[(df.iloc[:, 2] > 20)& ((df.iloc[:, 0] >=5) &(df.iloc[:, 0] <=20))]
# Out:
#       age embarked      fare  \
# 9    14.0        C   30.0708
# 24    8.0        S   21.0750
# 27   19.0        S  263.0000
# 50    7.0        S   39.6875
# 58    5.0        S   27.7500
# 59   11.0        S   46.9000
# 71   16.0        S   46.9000
# 86   16.0        S   34.3750
# 136  19.0        S   26.2833
# 145  19.0        S   36.7500
# 147   9.0        S   34.3750
# 165   9.0        S   20.5250
# 182   9.0        S   31.3875
# 233   5.0        S   31.3875
# 237   8.0        S   26.2500
# 266  16.0        S   39.6875
# 278   7.0        Q   29.1250
# 291  19.0        C   91.0792
# 307  17.0        C  108.9000
# 311  18.0        C  262.3750
# 329  16.0        C   57.9792
# 385  18.0        S   73.5000
# 419  10.0        S   24.1500
# 424  18.0        S   20.2125
# 427  19.0        S   26.0000
# 435  14.0        S  120.0000
# 480   9.0        S   46.9000
# 504  16.0        S   86.5000
# 505  18.0        C  108.9000
# 535   7.0        S   26.2500
# 541   9.0        S   31.2750
# 542  11.0        S   31.2750
# 546  19.0        S   26.0000
# 549   8.0        S   36.7500
# 550  17.0        C  110.8833
# 585  18.0        S   79.6500
# 634   9.0        S   27.9000
# 651  18.0        S   23.0000
# 683  14.0        S   46.9000
# 686  14.0        S   39.6875
# 689  15.0        S  211.3375
# 700  18.0        C  227.5250
# 720   6.0        S   33.0000
# 746  16.0        S   20.2500
# 748  19.0        S   53.1000
# 781  17.0        S   57.0000
# 787   8.0        Q   29.1250
# 791  16.0        S   26.0000
# 802  11.0        S  120.0000
# 813   6.0        S   31.2750
# 819  10.0        S   27.9000
# 853  16.0        S   39.4000
# 887  19.0        S   30.0000
#
#                                                   name  parch  passengerid  \
# 9                  Nasser, Mrs. Nicholas (Adele Achem)      0           10
# 24                       Palsson, Miss. Torborg Danira      1           25
# 27                      Fortune, Mr. Charles Alexander      2           28
# 50                          Panula, Master. Juha Niilo      1           51
# 58                        West, Miss. Constance Mirium      2           59
# 59                  Goodwin, Master. William Frederick      2           60
# 71                          Goodwin, Miss. Lillian Amy      2           72
# 86                              Ford, Mr. William Neal      3           87
# 136                       Newsom, Miss. Helen Monypeny      2          137
# 145                       Nicholls, Mr. Joseph Charles      1          146
# 147                   Ford, Miss. Robina Maggie "Ruby"      2          148
# 165    Goldsmith, Master. Frank John William "Frankie"      2          166
# 182              Asplund, Master. Clarence Gustaf Hugo      2          183
# 233                     Asplund, Miss. Lillian Gertrud      2          234
# 237                   Collyer, Miss. Marjorie "Lottie"      2          238
# 266                          Panula, Mr. Ernesti Arvid      1          267
# 278                                 Rice, Master. Eric      1          279
# 291            Bishop, Mrs. Dickinson H (Helen Walton)      0          292
# 307  Penasco y Castellana, Mrs. Victor de Satode (M...      0          308
# 311                         Ryerson, Miss. Emily Borie      2          312
# 329                       Hippach, Miss. Jean Gertrude      1          330
# 385                          Davies, Mr. Charles Henry      0          386
# 419                          Van Impe, Miss. Catharina      2          420
# 424                        Rosblom, Mr. Viktor Richard      1          425
# 427  Phillips, Miss. Kate Florence ("Mrs Kate Louis...      0          428
# 435                          Carter, Miss. Lucile Polk      2          436
# 480                     Goodwin, Master. Harold Victor      2          481
# 504                              Maioni, Miss. Roberta      0          505
# 505         Penasco y Castellana, Mr. Victor de Satode      0          506
# 535                             Hart, Miss. Eva Miriam      2          536
# 541               Andersson, Miss. Ingeborg Constanzia      2          542
# 542                  Andersson, Miss. Sigrid Elisabeth      2          543
# 546                  Beane, Mrs. Edward (Ethel Clarke)      0          547
# 549                     Davies, Master. John Morgan Jr      1          550
# 550                        Thayer, Mr. John Borland Jr      2          551
# 585                                Taussig, Miss. Ruth      2          586
# 634                                 Skoog, Miss. Mabel      2          635
# 651                                Doling, Miss. Elsie      1          652
# 683                        Goodwin, Mr. Charles Edward      2          684
# 686                           Panula, Mr. Jaako Arnold      1          687
# 689                  Madill, Miss. Georgette Alexandra      1          690
# 700  Astor, Mrs. John Jacob (Madeleine Talmadge Force)      0          701
# 720                  Harper, Miss. Annie Jessie "Nina"      1          721
# 746                        Abbott, Mr. Rossmore Edward      1          747
# 748                          Marvin, Mr. Daniel Warner      0          749
# 781          Dick, Mrs. Albert Adrian (Vera Gillespie)      0          782
# 787                          Rice, Master. George Hugh      1          788
# 791                                Gaskell, Mr. Alfred      0          792
# 802                Carter, Master. William Thornton II      2          803
# 813                 Andersson, Miss. Ebba Iris Alfrida      2          814
# 819                       Skoog, Master. Karl Thorsten      2          820
# 853                          Lines, Miss. Mary Conover      1          854
# 887                       Graham, Miss. Margaret Edith      0          888
#
#      pclass     sex  sibsp  survived        ticket   title  family_size
# 9         2  female      1         1        237736     Mrs            1
# 24        3  female      3         0        349909    Miss            4
# 27        1    male      3         0         19950      Mr            5
# 50        3    male      4         0       3101295  Master            5
# 58        2  female      1         1    C.A. 34651    Miss            3
# 59        3    male      5         0       CA 2144  Master            7
# 71        3  female      5         0       CA 2144    Miss            7
# 86        3    male      1         0    W./C. 6608      Mr            4
# 136       1  female      0         1         11752    Miss            2
# 145       2    male      1         0    C.A. 33112      Mr            2
# 147       3  female      2         0    W./C. 6608    Miss            4
# 165       3    male      0         1        363291  Master            2
# 182       3    male      4         0        347077  Master            6
# 233       3  female      4         1        347077    Miss            6
# 237       2  female      0         1    C.A. 31921    Miss            2
# 266       3    male      4         0       3101295      Mr            5
# 278       3    male      4         0        382652  Master            5
# 291       1  female      1         1         11967     Mrs            1
# 307       1  female      1         1      PC 17758     Mrs            1
# 311       1  female      2         1      PC 17608    Miss            4
# 329       1  female      0         1        111361    Miss            1
# 385       2    male      0         0  S.O.C. 14879      Mr            0
# 419       3  female      0         0        345773    Miss            2
# 424       3    male      1         0        370129      Mr            2
# 427       2  female      0         1        250655    Miss            0
# 435       1  female      1         1        113760    Miss            3
# 480       3    male      5         0       CA 2144  Master            7
# 504       1  female      0         1        110152    Miss            0
# 505       1    male      1         0      PC 17758      Mr            1
# 535       2  female      0         1  F.C.C. 13529    Miss            2
# 541       3  female      4         0        347082    Miss            6
# 542       3  female      4         0        347082    Miss            6
# 546       2  female      1         1          2908     Mrs            1
# 549       2    male      1         1    C.A. 33112  Master            2
# 550       1    male      0         1         17421      Mr            2
# 585       1  female      0         1        110413    Miss            2
# 634       3  female      3         0        347088    Miss            5
# 651       2  female      0         1        231919    Miss            1
# 683       3    male      5         0       CA 2144      Mr            7
# 686       3    male      4         0       3101295      Mr            5
# 689       1  female      0         1         24160    Miss            1
# 700       1  female      1         1      PC 17757     Mrs            1
# 720       2  female      0         1        248727    Miss            1
# 746       3    male      1         0     C.A. 2673      Mr            2
# 748       1    male      1         0        113773      Mr            1
# 781       1  female      1         1         17474     Mrs            1
# 787       3    male      4         0        382652  Master            5
# 791       2    male      0         0        239865      Mr            0
# 802       1    male      1         1        113760  Master            3
# 813       3  female      4         0        347082    Miss            6
# 819       3    male      3         0        347088  Master            5
# 853       1  female      0         1      PC 17592    Miss            1
# 887       1  female      0         1        112053    Miss            0

# %% [markdown]
# **Question 10:** Replace the integer values in the `Pclass` columns with corresponding string data types. For example, replace 1 with 'Upper', 2 with 'Middle' and 3 with 'Lower'

# %%
df.pclass[df.pclass==1]='Upper'
df.pclass[df.pclass==2]='Middle'
df.pclass[df.pclass==3]='Lower'
df.head(10)
# Out:
#     age embarked     fare                                               name  \
# 0  22.0        S   7.2500                            Braund, Mr. Owen Harris
# 1  38.0        C  71.2833  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2  26.0        S   7.9250                             Heikkinen, Miss. Laina
# 3  35.0        S  53.1000       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4  35.0        S   8.0500                           Allen, Mr. William Henry
# 5  30.0        Q   8.4583                                   Moran, Mr. James
# 6  54.0        S  51.8625                            McCarthy, Mr. Timothy J
# 7   2.0        S  21.0750                     Palsson, Master. Gosta Leonard
# 8  27.0        S  11.1333  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9  14.0        C  30.0708                Nasser, Mrs. Nicholas (Adele Achem)
#
#    parch  passengerid  pclass     sex  sibsp  survived            ticket  \
# 0      0            1   Lower    male      1         0         A/5 21171
# 1      0            2   Upper  female      1         1          PC 17599
# 2      0            3   Lower  female      0         1  STON/O2. 3101282
# 3      0            4   Upper  female      1         1            113803
# 4      0            5   Lower    male      0         0            373450
# 5      0            6   Lower    male      0         0            330877
# 6      0            7   Upper    male      0         0             17463
# 7      1            8   Lower    male      3         0            349909
# 8      2            9   Lower  female      0         1            347742
# 9      0           10  Middle  female      1         1            237736
#
#     title  family_size
# 0      Mr            1
# 1     Mrs            1
# 2    Miss            0
# 3     Mrs            1
# 4      Mr            0
# 5      Mr            0
# 6      Mr            0
# 7  Master            4
# 8     Mrs            2
# 9     Mrs            1

# %% [markdown]
# **Question 11:** Using a pivot table, represent the male and female passengers in each of the three passenger classes.

# %%
#pivott=pd.pivot_table(df,index=['sex','pclass'])
pivott=df.pivot_table(values='survived', index='pclass', columns='sex',aggfunc=pd.Series.count)
pivott
# Out:
# sex     female  male
# pclass
# Lower      144   347
# Middle      76   108
# Upper       94   122

# %% [markdown]
# **Question 12 Part A:** Make a new column which classifies ages as the following: '0-20', '20-50' and '50-90'

# %%
con=[(df['age']<=20),
      ((df['age']>20)&(df['age']<=50)),
     (df['age']>50)]
agegroup=['0-20','20-50','50-90']
df['age_group'] = np.select(con, agegroup)
df.head(10)
# Out:
#     age embarked     fare                                               name  \
# 0  22.0        S   7.2500                            Braund, Mr. Owen Harris
# 1  38.0        C  71.2833  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2  26.0        S   7.9250                             Heikkinen, Miss. Laina
# 3  35.0        S  53.1000       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4  35.0        S   8.0500                           Allen, Mr. William Henry
# 5  30.0        Q   8.4583                                   Moran, Mr. James
# 6  54.0        S  51.8625                            McCarthy, Mr. Timothy J
# 7   2.0        S  21.0750                     Palsson, Master. Gosta Leonard
# 8  27.0        S  11.1333  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9  14.0        C  30.0708                Nasser, Mrs. Nicholas (Adele Achem)
#
#    parch  passengerid  pclass     sex  sibsp  survived            ticket  \
# 0      0            1   Lower    male      1         0         A/5 21171
# 1      0            2   Upper  female      1         1          PC 17599
# 2      0            3   Lower  female      0         1  STON/O2. 3101282
# 3      0            4   Upper  female      1         1            113803
# 4      0            5   Lower    male      0         0            373450
# 5      0            6   Lower    male      0         0            330877
# 6      0            7   Upper    male      0         0             17463
# 7      1            8   Lower    male      3         0            349909
# 8      2            9   Lower  female      0         1            347742
# 9      0           10  Middle  female      1         1            237736
#
#     title  family_size age_group
# 0      Mr            1     20-50
# 1     Mrs            1     20-50
# 2    Miss            0     20-50
# 3     Mrs            1     20-50
# 4      Mr            0     20-50
# 5      Mr            0     20-50
# 6      Mr            0     50-90
# 7  Master            4      0-20
# 8     Mrs            2     20-50
# 9     Mrs            1      0-20

# %% [markdown]
# **Question 12 Part B:** Using this new column, make a pivot table that represents how many males and females had survived in each age group.

# %%
df.pivot_table(index='age_group',columns='sex',aggfunc={'survived':sum})
# Out:
#           survived
# sex         female male
# age_group
# 0-20            53   31
# 20-50          164   72
# 50-90           16    6

# %% [markdown]
# **Congratulations on completing your first assignment!**
